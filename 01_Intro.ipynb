# %% [markdown]
# # Colab Basics
#
# - Side tabs: Table of contents/ Variable trackers/ Secrets/ File manager
# - Menu bar: File/ Runtime
# - Runtime instances: Getting GPU resources
# - Adding code and text
# - Executing cells
#
#
# **Resources**
#
# You can find more details [ here](https://colab.research.google.com/drive/1YKHHLSlG-B9Ez2-zf-YFxXTVgfC_Aqtt#scrollTo=CXnyoIOFGCYk)

# %% [markdown]
# # Basic Linux/Shell commands
# Distinguisher: Exclamation mark prefix

# %%
# Nvidia System Management Interface: Used to check GPU resources
# !nvidia-smi
# Out:
# Wed Feb  7 03:25:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  GRID A100X-8C                  On  | 00000000:04:00.0 Off |                    0 |
# | N/A   N/A    P0              N/A /  N/A |     35MiB /  8192MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1103      G   /usr/lib/xorg/Xorg                           35MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## File management

# %%
# Print working directory
# !pwd
# Out:
# /home/exouser/ME592_Spring2024/01_Intro

# %%
# List
# !ls
# Out:
# 01_Intro.ipynb	ME592_S24     lung.png	   rgb_pixels.png
# Demo_PCA.ipynb	elephant.png  placeholder  sample_weather.txt

# %%
# Make directory
#!mkdir tempdir

# !ls
# Out:
# 01_Intro.ipynb	ME592_S24     lung.png	   rgb_pixels.png
# Demo_PCA.ipynb	elephant.png  placeholder  sample_weather.txt

# %%
#!git clone https://github.com/me592content/ME592_Spring2025.git

# %% [markdown]
# **Resources**
#
# You can find more on shell commands [here](https://missing.csail.mit.edu/2020/shell-tools/) and learn more about git [here](https://github.com/git-guides)

# %% [markdown]
# ## Managing Python packages

# %%
#!pip list
# !conda list
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# archspec                  0.2.1                    pypi_0    pypi
# boltons                   23.0.0                   pypi_0    pypi
# brotli                    1.0.9                    pypi_0    pypi
# brotli-python             1.0.9           py311h6a678d5_7
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.19.1               h5eee18b_0
# ca-certificates           2023.12.12           h06a4308_0
# certifi                   2023.11.17               pypi_0    pypi
# cffi                      1.16.0                   pypi_0    pypi
# charset-normalizer        2.0.4                    pypi_0    pypi
# conda                     23.11.0                  pypi_0    pypi
# conda-content-trust       0.2.0                    pypi_0    pypi
# conda-libmamba-solver     23.12.0                  pypi_0    pypi
# conda-package-handling    2.2.0                    pypi_0    pypi
# conda-package-streaming   0.9.0                    pypi_0    pypi
# cryptography              41.0.7                   pypi_0    pypi
# distro                    1.8.0                    pypi_0    pypi
# fmt                       9.1.0                hdb19cb5_0
# icu                       73.1                 h6a678d5_0
# idna                      3.4                      pypi_0    pypi
# jsonpatch                 1.32                     pypi_0    pypi
# jsonpointer               2.1                      pypi_0    pypi
# krb5                      1.20.1               h143b758_1
# ld_impl_linux-64          2.38                 h1181459_1
# libarchive                3.6.2                h6ac8c49_2
# libcurl                   8.4.0                h251f7ec_1
# libedit                   3.1.20230828         h5eee18b_0
# libev                     4.33                 h7f8727e_1
# libffi                    3.4.4                h6a678d5_0
# libgcc-ng                 11.2.0               h1234567_1
# libgomp                   11.2.0               h1234567_1
# libmamba                  1.5.3                haf1ee3a_0
# libmambapy                1.5.3                    pypi_0    pypi
# libnghttp2                1.57.0               h2d74bed_0
# libsolv                   0.7.24               he621ea3_0
# libssh2                   1.10.0               hdbd6064_2
# libstdcxx-ng              11.2.0               h1234567_1
# libuuid                   1.41.5               h5eee18b_0
# libxml2                   2.10.4               hf1b16e4_1
# lz4-c                     1.9.4                h6a678d5_0
# menuinst                  2.0.1                    pypi_0    pypi
# ncurses                   6.4                  h6a678d5_0
# openssl                   3.0.12               h7f8727e_0
# packaging                 23.1                     pypi_0    pypi
# pcre2                     10.42                hebb0a14_0
# pip                       23.3.1                   pypi_0    pypi
# platformdirs              3.10.0                   pypi_0    pypi
# pluggy                    1.0.0                    pypi_0    pypi
# pybind11-abi              4                    hd3eb1b0_1
# pycosat                   0.6.6                    pypi_0    pypi
# pycparser                 2.21                     pypi_0    pypi
# pyopenssl                 23.2.0                   pypi_0    pypi
# pysocks                   1.7.1                    pypi_0    pypi
# python                    3.11.5               h955ad1f_0
# readline                  8.2                  h5eee18b_0
# reproc                    14.2.4               h295c915_1
# reproc-cpp                14.2.4               h295c915_1
# requests                  2.31.0                   pypi_0    pypi
# ruamel-yaml               0.17.21                  pypi_0    pypi
# ruamel.yaml               0.17.21         py311h5eee18b_0
# setuptools                68.2.2                   pypi_0    pypi
# sqlite                    3.41.2               h5eee18b_0
# tk                        8.6.12               h1ccaba5_0
# tqdm                      4.65.0                   pypi_0    pypi
# truststore                0.8.0                    pypi_0    pypi
# tzdata                    2023c                h04d1e81_0
# urllib3                   1.26.18                  pypi_0    pypi
# wheel                     0.41.2                   pypi_0    pypi
# xz                        5.4.5                h5eee18b_0
# yaml-cpp                  0.8.0                h6a678d5_0
# zlib                      1.2.13               h5eee18b_0
# zstandard                 0.19.0                   pypi_0    pypi
# zstd                      1.5.5                hc292b87_0

# %%
# Example of installing external pip package
#!pip install openai

# Example of installing external conda package
#!conda install <package_name>

# %% [markdown]
# **Resources**
#
# You can find more pip resources [here](https://pip.pypa.io/en/stable/user_guide/) and conda resources [here](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-pkgs.html)

# %% [markdown]
# # Python Intro

# %%
# !python --version
# Out:
# Python 3.9.7

# %% [markdown]
# ## Variables

# %%
# Assigning variables
x = 5
y = -1
z = x + y

# Printing variables
print(z)

# Printing variables with description text
print('The sum of x and y is:', z)

# Printing variables with description text using f strings
print(f'The sum of x and y is: {z}')
# Out:
# 4
# The sum of x and y is: 4
# The sum of x and y is: 4

# %% [markdown]
# ## Data Types and Operators

# %% [markdown]
# ### Lists

# %%
# Creating lists
x = list()
y = []
x = list((2, 1, 4, 8))
y = [2, 1, 4, 10, 20, 40]
print('About x:')
print('type(x) - ', type(x))
print('x       - ', x)
print('len(x)  - ',len(x))
print(' ')
print('About y:')
print('type(y) - ', type(y))
print('y       - ', y)
print('len(y)  - ',len(y))
# Out:
# About x:
# type(x) -  <class 'list'>
# x       -  [2, 1, 4, 8]
# len(x)  -  4
#
# About y:
# type(y) -  <class 'list'>
# y       -  [2, 1, 4, 10, 20, 40]
# len(y)  -  6

# %%
# Indexing lists
x_1 = x[2]
# Index slicing
y_1 = y[2:]
y_2 = y[2:4]
print('x[2]  - ', x_1)
print('y_1 (y[2:])  - ', y_1)
print('y_2 (y[2:4]) - ', y_2)
# Out:
# x[2]  -  4
# y_1 (y[2:])  -  [4, 10, 20, 40]
# y_2 (y[2:4]) -  [4, 10]

# %%
# Append and Extend
x.append(y)
print(x)
y.extend(y_1)
print(y)
# Out:
# [2, 1, 4, 8, [2, 1, 4, 10, 20, 40]]
# [2, 1, 4, 10, 20, 40, 4, 10, 20, 40]

# %% [markdown]
# ### Tuples

# %%
# Tuples
x = tuple((2, 2))
y = (2, 2)
print(type(x))
print(x)
print(type(y))
print(y)
# Out:
# <class 'tuple'>
# (2, 2)
# <class 'tuple'>
# (2, 2)

# %%
print(x[-1])
print(y[0])
# Out:
# 2
# 2

# %%
# Tuple elements are not mutable
x[0] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Tuple elements are not mutable
# ----> 2 x[0] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Dictionaries

# %%
# Dict
# Dicts are nice if you need to store multiple different types of values in one location because of keys
dict = {} # or dict()
dict['int'] = 1
dict['str'] = 'string key'
dict['list'] = [1,2,3]
dict['tuple'] = (2,3)
dict['float'] = 0.
dict['inception'] = {'int':1, 'str':'hello', 'list':[1,2]}
print(dict.keys())

# %%
print(dict['int'])

# %%
inception_str = dict['inception']['str']
print(inception_str)

# %% [markdown]
# ### List Comprehension

# %%
# %%timeit
l = []
for i in range(100):
    l.append(i)

# %%
# %timeit a = [i for i in range(100)]

# %% [markdown]
# ### A even faster way to create a list

# %%
# %timeit a = list(range(100))

# %% [markdown]
# ## Functions

# %%
def func(x, m, b):
    return m * x + b

# %%
y = func(1., 2., 0.5)
y

# %% [markdown]
# ## Classes

# %%
class Model(object):
    # class initialization and attributes
    def __init__(self, params, model_type, name='Neural Network'):
        self.name = name
        self.params = params
        self.model_type = model_type

    # internal functions denoted by __.__
    # str
    def __str__(self):
        return 'Readable string : This is a '+ self.model_type + ' ' + self.name + ' with ' + str(self.params) + ' params'

    # representation
    def __repr__(self):
        return self.model_type + ' ' + self.name + ' with ' + str(self.params) + ' params'

    # method
    def printParams(self, multiplier):
        print(self.params*multiplier)

# %%
m1 = Model(5, 'Supervised', 'LinearRegression')

# %%
m1

# %%
print(m1)

# %%
m1.name

# %%
m1.printParams(10)

# %% [markdown]
# # Important Python Packages

# %% [markdown]
# ## Numpy

# %%
import numpy as np
# numpy type vs native python type
x = np.array([1,2,3])

print(x[0].dtype)
print(type(1))

x = np.arange(10)
print(x)

# %% [markdown]
# ## Matplotlib

# %%
# plotting example
import matplotlib.pyplot as plt

t = np.linspace(0,2,100)
x = np.sin(2*np.pi*t)
y = np.cos(2*np.pi*t)

plt.plot(t,x)
plt.plot(t,y)
plt.grid()
plt.show()

# %% [markdown]
# ## OpenCV

# %% [markdown]
# ### Loading an Image

# %%
import cv2
from PIL import Image
from IPython.display import display

# Last argument 1 is for rgb, 0 is for grayscale
img_rgb = cv2.imread('/home/exouser/ME592_Spring2024/01_Intro/rgb_pixels.png', 1)
# Img source: https://www.cnet.com/tech/home-entertainment/led-lcd-vs-oled/

# Checking shape and datatype of the loaded image
print(f'The shape and datatype of img_rgb is :{img_rgb.shape}, and {type(img_rgb)}\n')

# Show the original image
display(Image.fromarray(img_rgb))

# %%
# Be careful of the RGB channel sequence when using different image processing packages, some has a sequence of RGB, while some is BGR
display(Image.fromarray(img_rgb[:100,:100,:]))
display(Image.fromarray(img_rgb[:100,:100,0]))
display(Image.fromarray(img_rgb[:100,:100,1]))
display(Image.fromarray(img_rgb[:100,:100,2]))

# %%
img = cv2.imread('/home/exouser/ME592_Spring2024/01_Intro/elephant.png', 1)
display(Image.fromarray(img))

# %%
# Source: https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_canny/py_canny.html
# Arguments are (img, threshold1, threshold2)
# img[:,:257,:] means we are cropping the image through matrix slicing. We are getting all the rows, columns until the 256th, and all RGB channels
edges = cv2.Canny(img[:,:257,:], 100, 200)

display(Image.fromarray(img[:,:257,:]))
display(Image.fromarray(edges))

# %%
# Try changing kernel size and observe what happens
kernel = np.ones((10,10), np.float32)/100

# Arguments are (source_image, depth, kernel)
dst = cv2.filter2D(src=img, ddepth=-1, kernel=kernel)

plt.subplot(121)
plt.imshow(img[:,:257,:]),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122)
plt.imshow(dst[:,:257,:]),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Histogram Equalization

# %%
img = cv2.imread('/home/exouser/ME592_Spring2024/01_Intro/lung.png', 0)
print(img)
print(img.dtype)
print(img.shape)
display(Image.fromarray(img))

# %%
# Arguments are (img, bins, range)
_ = plt.hist(img.flatten(),256,[0,256], color = 'r')

# %%
# Histogram equalization can be used to improve constrast of img
equ = cv2.equalizeHist(img)
_ = plt.hist(equ.flatten(),256,[0,256], color = 'r')

# %%
display(Image.fromarray(img))
display(Image.fromarray(equ))

# %% [markdown]
# ### Thesholding

# %%
threshold_value = 150

# Apply the threshold
_, thresholded_image = cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)

# Display the thresholded image
display(Image.fromarray(thresholded_image))

# %% [markdown]
# ### Denoising

# %%
# Median filter is one way of denoising
img = cv2.imread('/home/exouser/ME592_Spring2024/01_Intro/elephant.png')[:,:257,:]
median = cv2.medianBlur(img, 3)
edges = cv2.Canny(median,100,200)


display(Image.fromarray(img))
display(Image.fromarray(cv2.Canny(img,100,200)))
display(Image.fromarray(median))
display(Image.fromarray(edges))

# %% [markdown]
# More Details on different image processing operations can be found in:
#
#
# 1.   https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_core/py_table_of_contents_core/py_table_of_contents_core.html
# 2.   https://scikit-image.org/docs/stable/auto_examples/index.html

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
timedata = pd.read_csv('/home/exouser/ME592_Spring2024/01_Intro/sample_weather.txt')

# %%
#timedata['Date'] = pd.to_datetime(timedata['Date'])  # Convert 'Date' to datetime
#timedata.set_index('Date', inplace=True)  # Set 'Date' as the index
timedata.plot()

# %%
timedata.describe()

# %%
timedata.isnull()

# %%
timedata_np = timedata.to_numpy()
print(timedata_np.shape)

# %%
plt.figure
plt.plot(timedata_np[:,1])
plt.show()

# %%
import scipy.signal
# can be used to compue moving average
def apply_convolution(sig, window):
    conv = np.repeat([0., 1., 0.], window)
    print('Convolution Kernel:', conv)
    filtered = scipy.signal.convolve(sig, conv, mode='same') / window
    return filtered

# apply a median filter, arguments are (volume, kernel)
filtered = scipy.signal.medfilt(timedata_np[:,1], 7)
# apply a convolution filter
convolved = apply_convolution(timedata_np[:,1], 20)
plt.plot(filtered)
plt.show()
plt.plot(convolved)
plt.show()

# %% [markdown]
# More details on time series processing can be found at
# 1. https://docs.scipy.org/doc/scipy/reference/signal.html
# 2. https://dynamictimewarping.github.io/
# 3. https://docs.scipy.org/doc/scipy/reference/tutorial/fft.html#

# %% [markdown]
# ## Dimensionality Reduction

# %%
from keras.datasets.mnist import  load_data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
_, (images, labels) = load_data()
print(images.shape, labels.shape)
# Out:
# 2024-02-06 22:21:09.772657: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# (10000, 28, 28) (10000,)

# %%
idx = np.random.randint(0, len(images))
plt.imshow(images[idx])
print(labels[idx])
plt.show()
# Out:
# 9

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(images.reshape(10000,28*28))
pca_result.shape
# Out:
# (10000, 2)

# %%
plt.figure()
plt.scatter(pca_result[:,0], pca_result[:,1], c=labels)
plt.colorbar()
plt.show()

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
import time
start = time.time()
tsne_results = tsne.fit_transform(images.reshape(10000,28*28))
end = time.time()
print('Time', end-start)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.003s...
# [t-SNE] Computed neighbors for 10000 samples in 2.504s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 439.058101
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.497032
# [t-SNE] KL divergence after 300 iterations: 2.835792
# Time 12.622967958450317

# %%
plt.scatter(tsne_results[:,0], tsne_results[:,1], c=labels)
plt.colorbar()
plt.show()

# %%
# applying PCA n high-dimensional data, then using t-SNE can speed up process
pca = PCA(n_components=50)
pca_result_int = pca.fit_transform(images.reshape(10000,28*28))
start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(pca_result_int)
end = time.time()
print('Time', end-start)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.000s...
# [t-SNE] Computed neighbors for 10000 samples in 1.837s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 347.445140
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.157974
# [t-SNE] KL divergence after 300 iterations: 2.767784
# Time 12.145222663879395

# %%
plt.figure()
plt.scatter(tsne_results[:,0], tsne_results[:,1], c=labels)
plt.colorbar()
plt.show()
